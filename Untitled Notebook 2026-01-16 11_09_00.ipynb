# %%
# %sql
select * from analytics_star_schema.deltashare.customers limit 5

# %%
# %sql
select * from analytics_star_schema.deltashare.fact_sales_0 limit 5

# %%
# %sql
select * from analytics_star_schema.deltashare.sales_orders limit 5

# %%
df = spark.read.json('/Volumes/databricks_simulated_retail_customer_data/v01/retail-pipeline/customers/stream_json/01.json')

display(df.limit(5))

# %%
df = spark.read.json('/Volumes/databricks_simulated_retail_customer_data/v01/retail-pipeline/orders/stream_json/01.json')

display(df.limit(5))

# %%
df = spark.read.json('/Volumes/databricks_simulated_retail_customer_data/v01/retail-pipeline/status/stream_json/01.json')

display(df.limit(5))
