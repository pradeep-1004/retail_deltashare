# %%
df = spark.read.table('databricks_simulated_retail_customer_data.v01.customers')

display(df.limit(10))

# %%
df.count()

# %%
df.select("customer_id").distinct().count()

# %%
df.select("state").distinct().count()

# %%
df.select('tax_code').distinct().count()

# %%
df_cust = spark.read.table('databricks_simulated_retail_customer_data.v01.customers')

df_sales = spark.read.table('databricks_simulated_retail_customer_data.v01.sales')

df_sales_orders = spark.read.table('databricks_simulated_retail_customer_data.v01.sales_orders')

display(df_cust.limit(10))

display(df_sales.limit(10))

display(df_sales_orders.limit(10))

# %%
df_csv_cust = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv')

display(df_csv_cust.limit(10))

# %%
df_csv_sales = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales.csv')

display(df_csv_sales.limit(10))

# %%
df_csv_sales_orders = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales_orders.csv')

display(df_csv_sales_orders.limit(10))

# %%
df_cust_tbl = spark.read.table('databricks_simulated_retail_customer_data.v01.customers')

# %%
df_cust_vol = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv')

# %%
#count 

print('tbl_cust_count:' , df_cust_tbl.count())
print('vol_cust_count:' , df_cust_vol.count())

# %%
#sales_count

sales_tbl = spark.read.table('databricks_simulated_retail_customer_data.v01.sales')
sales_vol = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales.csv')

print('sales_tbl_count:' , sales_tbl.count())
print('sales_vol_count:' , sales_vol.count())

# %%
#sales_count

sales_orders_tbl = spark.read.table('databricks_simulated_retail_customer_data.v01.sales_orders')
sales_orders_vol = spark.read.option('header',True).csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales_orders.csv')

print('sales_ord_tbl_count:' , sales_orders_tbl.count())
print('sales_ord_vol_count:' , sales_orders_vol.count())
