# %%
df = spark.read.option('header', 'true').csv('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/customers.csv')

display(df.limit(10))
df.explain()

# %%
display(spark.read.table('databricks_simulated_retail_customer_data.v01.customers').limit(10))

# %%
df2 = spark.read.format('json')\
        .load('/Volumes/databricks_simulated_retail_customer_data/v01/retail-pipeline/status/stream_json/00.json')

display(df2.limit(10))

df2.count()

# %%
df.printSchema()

# %%
df_sales = spark.read.format('csv')\
            .option('header',True)\
            .load('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales.csv')

display(df_sales.limit(10))

# %%
df_sales.printSchema()

# %%
df_sales_ord = spark.read.format('csv')\
            .option('header',True)\
            .load('/Volumes/databricks_simulated_retail_customer_data/v01/source_files/sales_orders.csv')

df_sales_ord.printSchema()
